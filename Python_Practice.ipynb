# %% [markdown]
# # Python Practice
#
# [Open this notebook in Google Colab](https://colab.research.google.com/github/MNHassan2026/AAI614_Hassan/blob/main/Python_Practice.ipynb)

# %%
# Simple Python practice

numbers = [10, 20, 30, 40, 50]

print("Numbers:", numbers)
print("Average:", sum(numbers) / len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
# Out:
# Numbers: [10, 20, 30, 40, 50]
# Average: 30.0
# Maximum: 50
# Minimum: 10
